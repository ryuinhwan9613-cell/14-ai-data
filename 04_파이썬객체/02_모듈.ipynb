# %%
import module1

print(module1.add(3,4))
print(module1.sub(5,2))
# Out:
# 7
# 3

# %%
from module1 import add, sub

print(add(10, 20))
print(sub(10, 30))
# Out:
# 30
# -20

# %%
from module1 import * # * module1의 모든 함수를 다 가져오기

print(add(10, 20))
print(sub(10, 30))
# Out:
# 30
# -20
