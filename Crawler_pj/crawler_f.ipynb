# %%
import requests                         # pip install requests
from bs4 import BeautifulSoup           # pip install beautifulsoup4

# url = "https://www.yna.co.kr/news"
url = "https://www.yna.co.kr/sports/baseball"
headers = {"User-Agent": "Mozilla/5.0"}

try:
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    print("--- 실시간 스포츠 야구 뉴스 ---\n")

    all_tags = soup.find_all(['strong', 'a'])
    
    news_list = []

    count = 0
    for tag in all_tags:
        title = tag.get_text().strip()
        
        if len(title) > 20 and title not in news_list:
            news_list.append(title) 
            count += 1
            print(f"{count}. {title}")
            print("-" * 50)
            
            if count >= 10: 
                break

except Exception as e:
    print(f"에러 발생: {e}")
# Out:
# --- 실시간 스포츠 야구 뉴스 ---
#
# 1. 삼성, KBO리그 최초 3천승 위업…강민호는 최초 2천500출장(종합2보)
# --------------------------------------------------
# 2. '1천767일' 만에 선발 등판 키움 배동현 "팀 3연패 끊어서 기뻐"
# --------------------------------------------------
# 3. [프로야구 대전전적] kt 14-11 한화
# --------------------------------------------------
# 4. [프로야구 창원전적] NC 5-4 롯데
# --------------------------------------------------
# 5. 삼성, KBO리그 최초 3천승 위업…강민호는 최초 2천500출장(종합)
# --------------------------------------------------
# 6. [프로야구 잠실전적] LG 7-2 KIA
# --------------------------------------------------
# 7. 배동현 5이닝 무실점·이주형 3타점…3연패 끊은 키움
# --------------------------------------------------
# 8. [프로야구 인천전적] 키움 11-2 SSG
# --------------------------------------------------
# 9. 삼성, KBO리그 최초 3천승 위업…강민호는 최초 2천500출장
# --------------------------------------------------
# 10. [프로야구 대구전적] 삼성 13-3 두산
# --------------------------------------------------
