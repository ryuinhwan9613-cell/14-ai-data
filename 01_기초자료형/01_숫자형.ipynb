# %%
# 정수형

a = 123  # 파이썬에서는 = 기호는 변수를 선언한다는 개념 
b = -170
c = 0

type(a) # type()는 형태를 확인하는 함수 # int는 정수
# Out:
# int

# %%
# 실수형 

a = 1.2E10 # 10의 10승
b = 4.3E-10 # 10의 -10승
c = 3.14

type(c) # float는 실수
a # print(a)
type(a)
# Out:
# float

# %%
# 8진수와 16진수

a = 0o177
a
# Out:
# 127

# %%
8 ** 2 + 8 * 7 + 7 # **은 제곱
# Out:
# 127

# %%
a = 0x8ff
a
# Out:
# 2303

# %%
(16 ** 2 * 8) + (16 * 15) + (15)
# Out:
# 2303

# %%
# 사칙연산

a = 3
b = 4

print(a+b)  # ctrl + shift + alt 기능 사용하기
print(a-b)
print(a*b)
print(a/b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
a   # 위의 커널에서 지정해도 메모리 남음
# Out:
# 3

# %%
a = 3
b = 4

a ** b
# Out:
# 81

# %%
16 ** 1/2 # 제곱근 루트
# Out:
# 8.0

# %%
# 나눗셈 후 나머지를 반환하는 % 연산자

7 % 3
# Out:
# 1

# %%
# 나눗셈 후 몫을 반환하는 // 연산자

7 // 3
# Out:
# 2

# %%
# 복합연산자

a = 1
a = a + 1   # 오른쪽 항에 먼저 대입 (덮어쓰기) 
print(a)
# Out:
# 2

# %%
a =  1
a += 1 # a = a + 1 이랑 같은 거임용
print(a)

a -= 1 # a = a - 1
a *= 1 # a = a * 1
a /= 1 # a = a / 1
# Out:
# 2
