# %% [markdown]
# 문제 1. 튜플 생성과 기본 구조
#
# 다음 조건을 만족하는 프로그램을 작성하시오.
#
# 1) 정수 1, 2, 3, 4, 5를 담은 튜플을 생성하시오.
# 2) 문자열 "red", "green", "blue"를 담은 튜플을 생성하시오.
# 3) 요소가 하나뿐인 튜플을 올바르게 생성하시오. (주의: 쉼표 필요)
# 4) 빈 튜플을 두 가지 방법((), tuple())으로 생성하시오.
# 5) 괄호 없이 튜플을 생성하시오. (패킹)
# 6) 각 튜플의 길이(len)와 자료형(type)을 출력하시오.
#
# a = (1, 2, 3, 4, 5)
# b = ("red", "green", "blue")
# c = (1,)
# d = ()
# e = tuple()
# f = 1,
#
# print(len(a),type(a))
# print(len(b),type(b))
# print(len(c),type(c))
# print(len(d),type(d))
# print(len(e),type(e))
# print(len(f),type(f))
#
#
# 문제 2. 튜플 인덱싱
#
# 아래 튜플이 주어졌을 때, 다음을 출력하시오.
#
# colors = ("빨강", "주황", "노랑", "초록", "파랑", "남색", "보라")
#
# 1) 첫 번째 요소
# 2) 마지막 요소 (음수 인덱스 사용)
# 3) 세 번째 요소
# 4) 뒤에서 세 번째 요소
# 5) 인덱스 4에 해당하는 요소
#
# colors = ("빨강", "주황", "노랑", "초록", "파랑", "남색", "보라")
#
# print(colors[0])
# print(colors[-1])
# print(colors[2])
# print(colors[-3])
# print(colors[4])
#
#
# 문제 3. 딕셔너리 기본 개념
# 다음 질문에 답하시오.
#
# 1. 딕셔너리는 무엇으로 구성되어 있는가?
#
# 키, 값
#
# 2. 딕셔너리와 리스트의 가장 큰 차이점은 무엇인가?
#
# 딕셔너리는 키와 값의 쌍으로 저장해서 순서가 아닌 고유한 키를 통해 접근하고
# 리스트는 순서에 따라 일렬로 저장한다.
#
# 3. 다음 중 딕셔너리의 Key로 사용할 수 없는 것은? (이유도 함께 설명)
#    - a) 숫자 (1, 2, 3)
#    - b) 문자열 ("name", "age")
#    - c) 리스트 ([1, 2, 3])
#    - d) 튜플 ((1, 2, 3))
#
# c  , 딕셔너리의 Key의 필수조건은 불변성이기 때문입니다.
# 리스트의 경우 가변 자료형이기 때문에 불가능합니다.
#
# 문제 4. 코드 읽기
# 다음 코드의 실행하시오
#
# student = {'name': '김철수', 'age': 20, 'major': '컴퓨터공학'}
# print(student['name'])
# print(student['age'])
#
# 김철수
# 20
#
# 문제 5. 딕셔너리 생성 및 조작
# 다음 조건에 맞는 딕셔너리를 생성하고 조작하시오.
#
#
# # 1. 다음 정보를 담는 딕셔너리를 만드시오
# #    - 이름: 본인 이름
# #    - 나이: 본인 나이
# #    - 취미: 본인 취미 (리스트로 여러 개)
# #    - 거주지: 본인 거주지
#
# # 2. 위 딕셔너리에 '전공' 항목을 추가하시오
#
# # 3. '취미' 항목에 새로운 취미를 추가하시오
#
# # 4. '나이' 항목의 값을 1 증가시키시오
#
# # 5. 모든 key와 value를 출력하시오
#
# profile = {"이름": "류인환", "나이": 27, "취미": ["골프", "뉴스 시청"], "거주지": "부산광역시 대연동"}
#
# profile["전공"] = "메카트로닉스공학"
# profile["취미"].append("축구")
# profile["나이"] += 1  # profile["나이] = profile["나이] + 1
# print(profile)
#
# 문제 6. 딕셔너리 함수 활용
# 다음 딕셔너리가 주어졌을 때, 각 요구사항을 수행하시오.
#
#
# fruits = {
#     'apple': 1000,
#     'banana': 1500,
#     'orange': 2000,
#     'grape': 3000
# }
#
# # 1. 모든 과일 이름(key)을 리스트로 출력하시오
#
# print(fruits.keys())
#
# # 2. 모든 가격(value)을 리스트로 출력하시오
#
# print(fruits.values())
#
#
# # 3. 'banana'의 가격을 출력하시오
#
# print(fruits.get("banana"))   # fruits["banana"]
#
#
# # 4. 'melon'이 딕셔너리에 있는지 확인하시오
#
# print("melon" in fruits)  # 불 형태로 결과 값이 나옴
#
# # 5. 'grape'를 pop() 함수를 사용하여 삭제하고, 삭제된 값을 출력하시오
#
# result = fruits.pop("grape")
# print(result)
#
# 문제 7. 성적 관리 프로그램
# 학생들의 성적을 관리하는 프로그램을 작성하시오.
#
# # 다음 학생들의 성적 정보를 딕셔너리로 저장하시오
# # 학생1: 이름=김민수, 국어=85, 영어=90, 수학=78
# # 학생2: 이름=이영희, 국어=92, 영어=88, 수학=95
# # 학생3: 이름=박철수, 국어=78, 영어=85, 수학=82
#
# # 요구사항:
# # 1. 각 학생의 총점과 평균을 계산하여 딕셔너리에 추가
# # 2. 각 학생의 정보를 보기 좋게 출력
#
# students = [
#             {"이름": "김민수", "국어": 85, "영어": 90, "수학": 78},
#             {"이름": "이영희", "국어": 92, "영어": 88, "수학": 95},
#             {"이름": "박철수", "국어": 78, "영어": 85, "수학": 82}
#            ]
#
# print("=== 학생 성적 관리 ===")
#
# s1 = students[0]
# s1["총점"] = s1["국어"] + s1["영어"] + s1["수학"]
# s1["평균"] = s1["총점"] / 3
#
# print(f"이름: {s1["이름"]}")
# print(f"국어: {s1["국어"]}점",",",f"영어: {s1["영어"]}점",",",f"수학: {s1["수학"]}점")
# print(f"총점: {s1["총점"]}점",",",f"평균: {s1["평균"]:.2f}점")  # 변수 뒤에 :.2f f는 float # round 이용해도 된다.
#
# print("---")
#
# s2 = students[1]
# s2["총점"] = s2["국어"] + s2["영어"] + s2["수학"]
# s2["평균"] = s2["총점"] / 3
#
# print(f"이름: {s2["이름"]}")
# print(f"국어: {s2["국어"]}점",",",f"영어: {s2["영어"]}점",",",f"수학: {s2["수학"]}점")
# print(f"총점: {s2["총점"]}점",",",f"평균: {s2["평균"]:.2f}점")
#
# print("---")
#
# s3 = students[2]
# s3["총점"] = s3["국어"] + s3["영어"] + s3["수학"]
# s3["평균"] = s3["총점"] / 3
#
# print(f"이름: {s3["이름"]}")
# print(f"국어: {s3["국어"]}점",",",f"영어: {s3["영어"]}점",",",f"수학: {s3["수학"]}점")
# print(f"총점: {s3["총점"]}점",",",f"평균: {s3["평균"]:.2f}점")
#
# print("---")
#
# 출력
#
# === 학생 성적 관리 ===
# 이름: 김민수
# 국어: 85점 , 영어: 90점 , 수학: 78점
# 총점: 253점 , 평균: 84.33점
# ---
# 이름: 이영희
# 국어: 92점 , 영어: 88점 , 수학: 95점
# 총점: 275점 , 평균: 91.67점
# ---
# 이름: 박철수
# 국어: 78점 , 영어: 85점 , 수학: 82점
# 총점: 245점 , 평균: 81.67점
# ---
#
# **출력 예시:**
#
# === 학생 성적 관리 ===
# 이름: 김민수
# 국어: 85점, 영어: 90점, 수학: 78점
# 총점: 253점, 평균: 84.33점
# ---
# 이름: 이영희
# 국어: 92점, 영어: 88점, 수학: 95점
# 총점: 275점, 평균: 91.67점
# ---
# 이름: 박철수
# 국어: 78점, 영어: 85점, 수학: 82점
# 총점: 245점, 평균: 81.67점
# ---
#
#
#
# 문제 8. 단어 카운터
# 문자열에서 각 단어가 몇 번 등장하는지 세는 프로그램을 작성하시오.
#
# text = "python is great python is fun python is powerful"
#
# # 요구사항:
# # 1. 문자열을 공백으로 분리하여 단어 리스트 만들기
# # 2. 각 단어의 등장 횟수 세기
# # 3. 결과를 출력
#
# text = "python is great python is fun python is powerful"
#
# word = text.split()
# word_count = {}
#
# word_count["python"] = word.count("python")
# word_count["is"] = word.count("is")
# word_count["great"] = word.count("great")
# word_count["fun"] = word.count("fun")
# word_count["powerful"] = word.count("powerful")
#
# print(f"python: {word_count["python"]}번")
# print(f"is: {word_count["is"]}번")
# print(f"great: {word_count["great"]}번")
# print(f"fun: {word_count["fun"]}번")
# print(f"powerful: {word_count["powerful"]}번")
#
# 출력
#
# python: 3번
# is: 3번
# great: 1번
# fun: 1번
# powerful: 1번
#
# **출력 예시:**
#
# python: 3번
# is: 3번
# great: 1번
# fun: 1번
# powerful: 1번
#
#
#
# 문제 9. 중첩 딕셔너리
# 다음과 같은 중첩 딕셔너리를 다루는 문제를 해결하시오.
#
#
# school = {
#     '1반': {
#         '김철수': {'국어': 85, '영어': 90, '수학': 78},
#         '이영희': {'국어': 92, '영어': 88, '수학': 95}
#     },
#     '2반': {
#         '박민수': {'국어': 88, '영어': 85, '수학': 90},
#         '최지영': {'국어': 95, '영어': 92, '수학': 88}
#     }
# }
#
# # 요구사항:
# # 1. '1반' 김철수의 수학 점수를 출력하시오
# # 2. '2반' 박민수의 평균 점수를 계산하여 출력하시오
#
# school = {
#           '1반': {
#                   '김철수': {'국어': 85, '영어': 90, '수학': 78},
#                   '이영희': {'국어': 92, '영어': 88, '수학': 95}
#                  },
#           '2반': {
#                   '박민수': {'국어': 88, '영어': 85, '수학': 90},
#                   '최지영': {'국어': 95, '영어': 92, '수학': 88}
#                  }
#          }
#
# print(school["1반"]["김철수"]["수학"])       # print(school["1반"]["김철수"].get("수학") #print(school.get("1반").get("김철수").get("수학"))
#
# school["2반"]["박민수"]["평균"] = (school["2반"]["박민수"]["국어"] + school["2반"]["박민수"]["영어"] + school["2반"]["박민수"]["수학"]) / 3
# # a = school["2반"]["박민수"]["국어"
# # b = school["2반"]["박민수"]["영어"]
# # c = school["2반"]["박민수"]["수학"]
# # print(round((a + b + c/3),2)
#
# print(school["2반"]["박민수"]["평균"])
#
# 출력
#
# 78
# 87.66666666666667
#
# 문제 9-1.
# school = [
#         {'이름': '김철수', '국어': 85, '영어': 90, '수학': 78},
#         {'이름': '이영희', '국어': 92, '영어': 88, '수학': 95},
#         {'이름': '박민수', '국어': 88, '영어': 85, '수학': 90},
#         {'이름': '최지영', '국어': 95, '영어': 92, '수학': 88}
# ]
# # 요구사항:
# # 1. 최지영의 국어 점수를 출력하시오
# # 2. 이영희의 평균 점수를 계산하여 출력하시오
#
# school = [
#           {'이름': '김철수', '국어': 85, '영어': 90, '수학': 78},
#           {'이름': '이영희', '국어': 92, '영어': 88, '수학': 95},
#           {'이름': '박민수', '국어': 88, '영어': 85, '수학': 90},
#           {'이름': '최지영', '국어': 95, '영어': 92, '수학': 88}
#          ]
#
# a = school[3]["국어"]
# print(f"최지영의 국어 점수: {a}점")
#
# b = school[1]["평균"] = (school[1]["국어"] + school[1]["영어"] + school[1]["수학"]) / 3
# print(f"이영희의 평균 점수: {b}점")
#
# 출력
#
# 최지영의 국어 점수: 95점
# 이영희의 평균 점수: 91.66666666666667점
#
# 문제 10. 다음 코드의 실행 결과를 예상하시오.
#
# # 1)
# s1 = set("Hello")
# print(s1)
#
# {'e', 'H', 'l', 'o'}
#
# # 2)
# s2 = set([1, 2, 3, 2, 1, 3, 4])
# print(s2)
#
# {1, 2, 3, 4}
#
# # 3)
# s3 = {}
# print(type(s3))
#
# <class 'dict'>
#
#
# 문제 11. 두 반의 학생 명단 비교
#
# A반과 B반 학생 명단이 있습니다.
#
#
# a_class = {'김철수', '이영희', '박민수', '최지영', '홍길동'}
# b_class = {'박민수', '최지영', '정수민', '강호동', '이영희'}
#
# 다음 질문에 답하시오:
#
#
# # 1. 두 반 모두에 있는 학생 (교집합)
#
# a_class & b_class
#
# 출력
#
# {'박민수', '이영희', '최지영'}
#
#
# # 2. 두 반을 합친 전체 학생 (합집합)
#
# print(a_class | b_class)
#
# 출력
#
# {'정수민', '박민수', '강호동', '김철수', '홍길동', '이영희', '최지영'}
#
# # 3. A반에만 있는 학생 (차집합)
#
# print(a_class - b_class)
#
# 출력
#
# {'홍길동', '김철수'}
#
# # 4. B반에만 있는 학생 (차집합)
#
# print(b_class - a_class)
#
# 출력
#
# {'강호동', '정수민'}
#
# 문제 12. 집합 조작하기
#
# fruits = {'apple', 'banana', 'orange'}
#
#
# 다음 작업을 수행하는 코드를 작성하시오:
#
#
# # 1. 'grape'를 추가하시오
#
# # 2. 'melon', 'kiwi', 'mango'를 한 번에 추가하시오
#
# # 3. 'banana'를 제거하시오
#
# # 4. 집합에 'strawberry'가 있는지 확인하시오
#
# # 5. 모든 과일을 제거하고 빈 집합으로 만드시오
#
# fruits = {'apple', 'banana', 'orange'}
# fruits.add("grape") #1
# fruits.update(["melon", "kiwi", "mango"]) #2
# fruits.remove("banana") #3
# "strawberry" in fruits #4
# fruits.clear() #5
# print(fruits)
