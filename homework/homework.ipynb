# %% [markdown]
# 1. https://himzei.com 회원기입하고 자기소개를 작성해해주세요(각오, MBTI, 파이썬으로 구현하고 싶은 것 등)**
#
# 2. 파이썬은 어떤 종류의 프로그래밍 언어인가? 다음 빈칸을 채우시오.
# - 파이썬은 ( 인터프리터 ) 언어로, 코드를 한 줄씩 읽어서 바로 실행하는 ( 인터프리터 )가 필요하다.
#
# 3. 파이썬 공식 다운로드 사이트 주소를 쓰시오, 설치 시 패스옵션을 체크해야 하는 이유와 안 했을 경우 어떻게 해야 하는지 서술하시오.
# - python.org / 컴퓨터 어디서든 'python'이라는 명령어만 입력하면 바로 실행할 수 있게 하기 위해 패스옵션을 체크합니다.
#   만약 체크를 안 했을 경우에는 삭제하고 다시 설치 하거나 시스템 환경 변수 편집 메뉴에 들어가서 파이썬 설치 경로를 추가해 줄 수도 있습니다.
#
# 4. 파이썬 설치 후, 설치가 제대로 되었는지 확인하는 명령어를 쓰시오.
# - 명령 프롬프트(터미널)에서: python --version
#
# 5. 다음 중 파이썬의 특징으로 옳은 것을 모두 고르시오. ( 1, 3, 5 )
# ① 무료이며 오픈소스이다
# ② 컴파일 언어이다
# ③ 다양한 운영체제에서 실행 가능하다
# ④ 문법이 복잡하여 배우기 어렵다
# ⑤ 풍부한 라이브러리를 제공한다`
#
# 6. 명령 프롬프트(터미널)에서 파이썬 대화형 모드로 진입하는 명령어를 쓰시오.
# - python
#
# 7. 대화형 모드에서 빠져나오는 방법 2가지를 쓰시오.
# - exit() 또는 quit() 명령어를 사용하거나 ctrl + z를 입력한 후에 Enter를 누른다.
#
# 8. 대화형 모드에서 `>>>` 기호는 무엇을 의미하는가?
# - >>>는 파이썬이 명령어를 입력받을 준비가 되었다는 의미입니다. 또한 입력과 출력을 구분해 줍니다.
#
# 9. 파이썬 파일의 확장자는 무엇이며, 이 파일을 실행하는 명령어를 쓰시오.
# - 확장자: .py
# - 실행 명령어: python 파일명.py
#
# 10. 현재 폴더에 `hello.py` 파일이 있을 때, 이를 실행하는 명령어를 쓰시오.
# - python hello.py
#
# 11. 다음 상황에서 파일을 실행하는 명령어를 쓰시오.
# - 현재 위치: C:\Users\student
# - 파일 위치: C:\Users\student\projects\mycode.py
# - python projects\mycode.py
#
# 12. 다음 상황에서 파일을 실행하는 명령어를 쓰시오.
# - 현재 위치: C:\Users\student\documents
# - 파일 위치: C:\Users\student\projects\test.py
# - python ..\projects\test.py
#
# 13. 절대 경로(Absolute Path)와 상대 경로(Relative Path)의 차이를 설명하시오.
# - 절대 경로는 최상위 폴더를 기준으로 하는 변하지 않는 고유한 주소이며
#   상대 경로는 현재 작업 중인 폴더를 기준으로 대상의 위치를 나타내는 주소입니다.
#
# 14. 다음 중 절대 경로에 해당하는 것을 모두 고르시오. ( 3, 5 )
# ① hello.py
# ② ./scripts/main.py
# ③ C:\Users\student\code\app.py
# ④ ../data/file.txt
# ⑤ /home/user/projects/test.py
#
# 15. 상대 경로에서 사용하는 다음 기호의 의미를 쓰시오.
# (1) .  (점 하나) - 현재 위치한 폴더
# (2) .. (점 두 개) - 현재 폴더의 한 단계 상위 폴더
# (3) /  또는  \ - 폴더 사이의 구분
#
# 16. 명령 프롬프트에서 현재 디렉토리를 확인하는 명령어를 쓰시오.
# - cd
#
# 17. 명령 프롬프트에서 디렉토리를 이동하는 명령어를 쓰시오.
# 예: projects 폴더로 이동
# - cd projects
#
# 18.  IDE란 무엇의 약자이며, 한글로 무엇이라고 하는지 쓰시오. 또한 IDE의 역할을 간단히 설명하시오.
# - 약자: Integrated Development Environment
# - 한글: 통합 개발 환경
# - IDE의 역할은 코드 작성, 컴파일, 디버깅 등 소프트웨어 개발에 필요한 모든 도구를 하나의 프로그램 안에 통합하여 제공하는 것입니다.
#
# 19. 다음 중 파이썬 개발에 사용할 수 있는 IDE/에디터를 모두 고르시오. ( 1, 2, 4, 5, 7 )
# ① Visual Studio Code
# ② PyCharm
# ③ Photoshop
# ④ Sublime Text
# ⑤ IDLE
# ⑥ Excel
# ⑦ Jupyter Notebook
#
#
# ### 숫자 자료형
# ## ※ 모든 코드는 직접 파이썬에서 실행하여 결과를 확인한 후 작성하세요.
#
# 1. / 연산자와 // 연산자의 차이점을 설명하시오.
# - / 연산자는 소수점까지 계산하는 일반적인 나누기를 의미하며 항상 실수형으로 반환됩니다
#   // 연산자는 나눗셈 후에 몫을 반환하는 연산자로 나눈 결과에서 소수점 이하를 버리고 몫만 취합니다.
#
# 2. 다음 코드의 실행 결과를 쓰시오.
# print(17 % 5) - 2
# print(23 % 7) - 2
# print(100 % 3) - 1
#
# 3. % 연산자는 무엇을 구하는 연산자인지 설명하고, 실생활에서 활용할 수 있는 예시를 하나 들어 쓰시오.
# - % 연산자는 나눗셈 후에 나머지를 구하는 연산자이며 시간의 단위를 변환할 때 유용합니다.
#   예를 들어 100초가 몇 분 몇 초인지 계산할 때, 60으로 나눈 몫은 분이 되고 나머지는 초가 됩니다.
#
# 4. ** 연산자가 의미하는 것을 설명하시오.
# - ** 연산자는 거듭제곱을 의미합니다. 2 ** 3과 같이 ** 연산자 뒤에 3을 넣으면 2 X 2 X 2의 거듭제곱으로 사용되지만
#   2 ** 1/2과 같이 ** 연산자 뒤에 1/2를 넣으면 제곱근으로도 사용 가능합니다.
#
# 5. 다음 조건에 맞게 코드를 작성하시오.
# - 변수 x에 8진수 25를 저장 - x = 0o25
# - 변수 y에 16진수 FF를 저장 - y = 0xff
# - x와 y의 합을 출력 - 276
#
# 6. 원의 넓이를 계산하는 프로그램을 작성하시오.
# - 반지름(r)은 변수로 저장 (예: r = 5)
# - 원주율(pi)은 3.14159를 사용
# - 공식: 넓이 = π × r²
# - r = 5
#   pi = 3.14159
#   넓이 = pi * (r ** 2)
#
# 7. 복리 이자를 계산하는 프로그램을 작성하시오.
# - 원금(principal): 1,000,000원
# - 연이율(rate): 5% (0.05)
# - 기간(years): 3년
# - 공식: 최종금액 = 원금 × (1 + 연이율)^기간
# - principal = 1000000
#   rate = 0.05
#   years = 3
#   최종금액 = principal * (1 + rate) ** years
#
# ### 문자 자료형
# ## ※ 모든 코드는 직접 파이썬에서 실행하여 결과를 확인한 후 작성하세요.
#
# 1. 파이썬에서 문자열을 만드는 4가지 방법을 쓰시오
# - 큰따옴표로 둘러싸기
# - 작은따옴표로 둘러싸기
# - 큰따옴표 3개를 연속으로 둘러싸기
# - 작은따옴표 3개를 연속으로 둘러싸기
#
# 2. 다음 문자열을 출력하시오
# - Python's favorite food is perl
# - print("Python's favorite food is perl")
#
# 3. 다음 문자열을 출력하시오
# - "Python is very easy" he says
# - print('"Python is very easy" he says')
#
# 4. 다음 코드에서 에러가 발생하는 이유를 설명하고 올바르게 수정하시오
# - msg = 'It's a beautiful day
# - 에러 발생 이유: 'It'까지만 문자열로 인식하고 뒤의 나머지는 문자열로 인식하지 못하기 때문입니다.
# - 수정 : msg = "'It's a beautiful day"
#
# 5. 다음 이스케이프 코드의 의미를 쓰시오. (5점)
# (1) \n : 줄바꿈
# (2) \t : 탭
# (3) \\ : 백슬래시 출력
# (4) \' : 작은따옴표 출력
# (5) \" : 큰따옴표 출력
#
# 6. 다음 코드의 실행 결과를 쓰시오.
# - print("C:\\Users\\python\\test.py")
# - C:\Users\python\test.py
#
# 7. len() 함수는 무엇을 반환하는지 설명하시오
# = len() 함수는 요소의 전체 개수를 계산하여 정수로 반환하는 함수입니다.
#
# 8. 문자열 인덱싱에서 a[-1]이 의미하는 것을 설명하시오.
# - 문자열에서 맨 뒤의 첫 번째 즉, 마지막 문자를 의미합니다.
#
# 9. 다음 코드의 실행 결과를 쓰시오. (4점)
# a = "Life is too short, You need Python"
# print(a[12])
# print(a[-5])
# - s
#   y
#
# 10. 다음 코드의 실행 결과를 쓰시오.
# a = "Life is too short, You need Python"
# print(a[0:4])
# - Life
#
# 11. 문자열 "Hello World"에서 인덱싱을 이용하여 "WH"를 출력하는 코드를 작성하시오
# - a[-5] + a[0]
